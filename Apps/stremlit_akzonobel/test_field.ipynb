# %%
import streamlit as st
import pandas as pd
from pathlib import Path

# %%
file_path = Path('/home/hama/Downloads/AKZONOBEL 2023-TEMMUZ SATIŞ FİYAT LİSTESİ_csv.csv')

# %%
df = pd.read_csv(file_path)

# %%
df = df[['Marka','Grup','Malzeme','Malzeme.1','Brm Kg','2023\nFİYAT USD' ]]
df
# Out:
#        Marka           Grup     Malzeme  \
# 0    AKRİPOL      Y.MALZEME   0600638H1
# 1    AKRİPOL      Y.MALZEME   1616KCZ14
# 2    AKRİPOL      Y.MALZEME   1818KCZ14
# 3    AKRİPOL         Vernik  93911BVZ11
# 4    AKRİPOL  Sertleştirici  93912BBZ11
# ..       ...            ...         ...
# 931  AKRİPOL          TİNER    TT061650
# 932  SIKKENS          TİNER    TT066610
# 933  SIKKENS          TİNER    TT066650
# 934  AKRİPOL          TİNER     TT07671
# 935  AKRİPOL          TİNER    TT076750
#
#                                     Malzeme.1  Brm Kg 2023\nFİYAT USD
# 0         AKRİPOL AKRİMATİK MATLAŞTIRICI 1 LT   1.081         $ 16.92
# 1                   AKRİPOL ANTİSİLİKON 250ML   0.205          $ 3.23
# 2            AKRİPOL FAST-TOP ACCELERATOR 1/4   0.220          $ 2.81
# 3                        Akripol HS Vernik 1L   0.998          $ 9.12
# 4                 Akripol HS Sertleştirici 1L   0.977         $ 10.44
# ..                                        ...     ...             ...
# 931       AKRİPOL ANTİSTATİK YÜZEY TEM.TNR 5L   3.750         $ 19.30
# 932                 SIKKENS THINNER M-600 1LT   0.747          $ 5.74
# 933                 SIKKENS THINNER M-600 5LT   3.733         $ 29.15
# 934  AKRİPOL AS700 A.STATIK TEM. TİNERİ  1 LT   0.780          $ 5.35
# 935  AKRİPOL AS700 A.STATIK TEM. TİNERİ  5 LT   3.900         $ 19.64
#
# [936 rows x 6 columns]

# %%
# Out:
#      Marka   Grup  Malzeme  Malzeme.1  Brm Kg  2023\nFİYAT USD
# 0    False  False    False      False   False            False
# 1    False  False    False      False   False            False
# 2    False  False    False      False   False            False
# 3    False  False    False      False   False            False
# 4    False  False    False      False   False            False
# ..     ...    ...      ...        ...     ...              ...
# 931  False  False    False      False   False            False
# 932  False  False    False      False   False            False
# 933  False  False    False      False   False            False
# 934  False  False    False      False   False            False
# 935  False  False    False      False   False            False
#
# [936 rows x 6 columns]
